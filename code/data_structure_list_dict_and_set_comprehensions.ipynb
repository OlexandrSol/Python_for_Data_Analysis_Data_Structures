# %% [markdown]
# ###  Cпискові, словарні та множинні включення

# %%
import numpy as np

# %% [markdown]
# #### Спискове включення

# %% [markdown]
# [expr for val in collection if condition]

# %%
strings = ['a', 'as', 'bat', 'car', 'dove', 'python']

# %%
[x.upper() for x in strings if len(x) > 2]
# Out:
# ['BAT', 'CAR', 'DOVE', 'PYTHON']

# %% [markdown]
# #### Словарне включення

# %% [markdown]
# dict_comp = {key-expr : value-expr for value in collection if condition}

# %%
mapping = {x: x**2 for x in range(5)}

# %%
mapping
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %% [markdown]
# #### Множинне включення

# %% [markdown]
# set_comp = {expr for value in collection if condition}

# %%
unique_lengths = {len(word) for word in ["apple", "banana", "pear"] if len(word) > 4}

# %%
unique_lengths
# Out:
# {5, 6}

# %% [markdown]
# #### Вкладене спискове включення

# %%
all_data = [['John', 'Emily', 'Michael', 'Mary', 'Steven'], 
            ['Maria', 'Juan', 'Javier', 'Natalia', 'Pilar']]

# %%
all_data
# Out:
# [['John', 'Emily', 'Michael', 'Mary', 'Steven'],
#  ['Maria', 'Juan', 'Javier', 'Natalia', 'Pilar']]

# %%
# Створимо список з імен де є дві букви "а"
result = [name for names in all_data for name in names if name.count('a') >=2]

# %%
result
# Out:
# ['Maria', 'Natalia']

# %%
some_tuples = [(1, 2, 3), (4, 5, 6), (7, 8, 9)]

# %%
flattened = [x for tup in some_tuples for x in tup]

# %%
flattened
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
[[x for x in tup] for tup in some_tuples]
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
