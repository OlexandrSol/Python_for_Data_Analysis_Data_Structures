# %% [markdown]
# ### Індексні об'єкти

# %%
import pandas as pd
import numpy as np

# %%
obj = pd.Series(np.arange(3), index=['a', 'b', 'c'])

# %%
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
index = obj.index

# %%
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
# Індексні об'єкти незмінні
# index[1] = 'd' TypeError: Index does not support mutable operations

# %%
# Незмінність важлива
labels = pd.Index(np.arange(3))

# %%
labels
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
obj2 = pd.Series([1.5, -2.5, 0], index=labels)

# %%
obj2
# Out:
# 0    1.5
# 1   -2.5
# 2    0.0
# dtype: float64

# %%
obj2.index is labels
# Out:
# True

# %%
populations = {'Ohio': {2000: 1, 2001: 2, 2000:4}, 
               'Nevada': {2001: 3, 2002:3}}

# %%
frame = pd.DataFrame(populations)

# %%
frame
# Out:
#       Ohio  Nevada
# 2000   4.0     NaN
# 2001   2.0     3.0
# 2002   NaN     3.0

# %%
frame.columns
# Out:
# Index(['Ohio', 'Nevada'], dtype='object')

# %%
'Ohio' in frame.columns
# Out:
# True

# %%
2003 in frame.index
# Out:
# False

# %%
# На відміну від множин, індекс в pandas може мати дублі
pd.Index(['foo', 'foo', 'bar', 'bar'])
# Out:
# Index(['foo', 'foo', 'bar', 'bar'], dtype='object')
